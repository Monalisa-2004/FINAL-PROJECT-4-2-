# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.cluster import KMeans
from imblearn.over_sampling import SMOTE
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from sklearn.metrics import classification_report, confusion_matrix

# Load the dataset
data = pd.read_csv('UNSW_NB15_training-set.csv')

# Drop irrelevant features
data = data.drop(['id', 'attack_cat'], axis=1)

# Separate features and labels
X = data.drop('label', axis=1)  # 'label' is the target feature (0: Normal, 1: Attack)
y = data['label']

# Encode categorical features
categorical_columns = X.select_dtypes(include=['object']).columns
le = LabelEncoder()
for col in categorical_columns:
    X[col] = le.fit_transform(X[col])

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Handle class imbalance using SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, y)

# Apply KMeans Clustering
n_clusters = len(y_resampled.unique())
kmeans = KMeans(n_clusters=n_clusters, n_init=10, random_state=42)
kmeans_labels = kmeans.fit_predict(X_resampled)

# Append KMeans cluster labels as a new feature
X_resampled = pd.DataFrame(X_resampled)
X_resampled['cluster'] = kmeans_labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Reshape the input data for CNN
X_train = X_train.values.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.values.reshape(X_test.shape[0], X_test.shape[1], 1)

# Define the CNN model
model = models.Sequential()

# Input Layer
model.add(layers.Input(shape=(X_train.shape[1], 1)))

# Convolutional Layers with Batch Normalization
model.add(layers.Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling1D(pool_size=2))

model.add(layers.Conv1D(filters=256, kernel_size=3, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling1D(pool_size=2))

# Flatten Layer
model.add(layers.Flatten())

# Fully Connected Layers with Dropout
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.5))

# Output Layer (Binary Classification)
model.add(layers.Dense(1, activation='sigmoid'))

# Compile the Model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Add Callbacks: Early Stopping and Learning Rate Scheduler
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True
)
lr_scheduler = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6
)

# Train the Model
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stopping, lr_scheduler]
)

# Save the Model
model.save('nids_cnn_kmeans_model_optimized.keras')

# Evaluate on Test Data
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')

# Make Predictions
y_pred = model.predict(X_test)
y_pred_classes = (y_pred > 0.5).astype("int32")

# Confusion Matrix and Classification Report
print(confusion_matrix(y_test, y_pred_classes))
print(classification_report(y_test, y_pred_classes))
# Out:
# Epoch 1/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 36s 37ms/step - accuracy: 0.8444 - loss: 0.3633 - val_accuracy: 0.9396 - val_loss: 0.1451 - learning_rate: 1.0000e-04
# Epoch 2/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.9363 - loss: 0.1577 - val_accuracy: 0.9520 - val_loss: 0.1208 - learning_rate: 1.0000e-04
# Epoch 3/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.9456 - loss: 0.1370 - val_accuracy: 0.9497 - val_loss: 0.1184 - learning_rate: 1.0000e-04
# Epoch 4/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.9509 - loss: 0.1250 - val_accuracy: 0.9573 - val_loss: 0.1059 - learning_rate: 1.0000e-04
# Epoch 5/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 31s 34ms/step - accuracy: 0.9538 - loss: 0.1206 - val_accuracy: 0.9578 - val_loss: 0.1062 - learning_rate: 1.0000e-04
# Epoch 6/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.9554 - loss: 0.1136 - val_accuracy: 0.9602 - val_loss: 0.1001 - learning_rate: 1.0000e-04
# Epoch 7/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 29s 32ms/step - accuracy: 0.9572 - loss: 0.1125 - val_accuracy: 0.9613 - val_loss: 0.0967 - learning_rate: 1.0000e-04
# Epoch 8/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 31s 34ms/step - accuracy: 0.9577 - loss: 0.1072 - val_accuracy: 0.9624 - val_loss: 0.0957 - learning_rate: 1.0000e-04
# Epoch 9/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 31s 34ms/step - accuracy: 0.9580 - loss: 0.1089 - val_accuracy: 0.9634 - val_loss: 0.0943 - learning_rate: 1.0000e-04
# Epoch 10/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.9590 - loss: 0.1039 - val_accuracy: 0.9628 - val_loss: 0.0956 - learning_rate: 1.0000e-04
# Epoch 11/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 36ms/step - accuracy: 0.9600 - loss: 0.1011 - val_accuracy: 0.9637 - val_loss: 0.0927 - learning_rate: 1.0000e-04
# Epoch 12/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.9616 - loss: 0.0993 - val_accuracy: 0.9648 - val_loss: 0.0942 - learning_rate: 1.0000e-04
# Epoch 13/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.9599 - loss: 0.0979 - val_accuracy: 0.9602 - val_loss: 0.0958 - learning_rate: 1.0000e-04
# Epoch 14/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.9613 - loss: 0.0971 - val_accuracy: 0.9614 - val_loss: 0.0964 - learning_rate: 1.0000e-04
# Epoch 15/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 33s 36ms/step - accuracy: 0.9615 - loss: 0.1000 - val_accuracy: 0.9648 - val_loss: 0.0922 - learning_rate: 1.0000e-04
# Epoch 16/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.9643 - loss: 0.0915 - val_accuracy: 0.9650 - val_loss: 0.0926 - learning_rate: 1.0000e-04
# Epoch 17/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 36ms/step - accuracy: 0.9661 - loss: 0.0910 - val_accuracy: 0.9613 - val_loss: 0.0938 - learning_rate: 1.0000e-04
# Epoch 18/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 36ms/step - accuracy: 0.9646 - loss: 0.0908 - val_accuracy: 0.9656 - val_loss: 0.0892 - learning_rate: 1.0000e-04
# Epoch 19/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 33s 36ms/step - accuracy: 0.9643 - loss: 0.0902 - val_accuracy: 0.9644 - val_loss: 0.0921 - learning_rate: 1.0000e-04
# Epoch 20/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 33s 36ms/step - accuracy: 0.9637 - loss: 0.0915 - val_accuracy: 0.9627 - val_loss: 0.0923 - learning_rate: 1.0000e-04
# Epoch 21/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 33s 36ms/step - accuracy: 0.9641 - loss: 0.0900 - val_accuracy: 0.9667 - val_loss: 0.0870 - learning_rate: 1.0000e-04
# Epoch 22/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9652 - loss: 0.0896 - val_accuracy: 0.9679 - val_loss: 0.0874 - learning_rate: 1.0000e-04
# Epoch 23/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 34s 37ms/step - accuracy: 0.9651 - loss: 0.0879 - val_accuracy: 0.9652 - val_loss: 0.0906 - learning_rate: 1.0000e-04
# Epoch 24/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9661 - loss: 0.0854 - val_accuracy: 0.9632 - val_loss: 0.0932 - learning_rate: 1.0000e-04
# Epoch 25/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9651 - loss: 0.0874 - val_accuracy: 0.9675 - val_loss: 0.0854 - learning_rate: 1.0000e-04
# Epoch 26/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 34s 37ms/step - accuracy: 0.9658 - loss: 0.0846 - val_accuracy: 0.9668 - val_loss: 0.0863 - learning_rate: 1.0000e-04
# Epoch 27/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 34s 38ms/step - accuracy: 0.9658 - loss: 0.0864 - val_accuracy: 0.9668 - val_loss: 0.0890 - learning_rate: 1.0000e-04
# Epoch 28/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 33s 36ms/step - accuracy: 0.9666 - loss: 0.0826 - val_accuracy: 0.9679 - val_loss: 0.0841 - learning_rate: 1.0000e-04
# Epoch 29/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.9674 - loss: 0.0817 - val_accuracy: 0.9679 - val_loss: 0.0855 - learning_rate: 1.0000e-04
# Epoch 30/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.9672 - loss: 0.0855 - val_accuracy: 0.9682 - val_loss: 0.0877 - learning_rate: 1.0000e-04
# Epoch 31/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 40s 44ms/step - accuracy: 0.9688 - loss: 0.0781 - val_accuracy: 0.9674 - val_loss: 0.0873 - learning_rate: 1.0000e-04
# Epoch 32/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 37s 41ms/step - accuracy: 0.9680 - loss: 0.0799 - val_accuracy: 0.9664 - val_loss: 0.0853 - learning_rate: 1.0000e-04
# Epoch 33/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 41s 41ms/step - accuracy: 0.9683 - loss: 0.0789 - val_accuracy: 0.9671 - val_loss: 0.0853 - learning_rate: 1.0000e-04
# Epoch 34/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 35s 34ms/step - accuracy: 0.9700 - loss: 0.0761 - val_accuracy: 0.9690 - val_loss: 0.0817 - learning_rate: 5.0000e-05
# Epoch 35/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 31s 34ms/step - accuracy: 0.9701 - loss: 0.0775 - val_accuracy: 0.9689 - val_loss: 0.0831 - learning_rate: 5.0000e-05
# Epoch 36/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.9708 - loss: 0.0743 - val_accuracy: 0.9686 - val_loss: 0.0826 - learning_rate: 5.0000e-05
# Epoch 37/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.9728 - loss: 0.0704 - val_accuracy: 0.9692 - val_loss: 0.0810 - learning_rate: 5.0000e-05
# Epoch 38/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.9711 - loss: 0.0727 - val_accuracy: 0.9679 - val_loss: 0.0850 - learning_rate: 5.0000e-05
# Epoch 39/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.9716 - loss: 0.0724 - val_accuracy: 0.9701 - val_loss: 0.0817 - learning_rate: 5.0000e-05
# Epoch 40/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.9729 - loss: 0.0699 - val_accuracy: 0.9703 - val_loss: 0.0809 - learning_rate: 5.0000e-05
# Epoch 41/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.9724 - loss: 0.0708 - val_accuracy: 0.9700 - val_loss: 0.0802 - learning_rate: 5.0000e-05
# Epoch 42/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 33s 36ms/step - accuracy: 0.9703 - loss: 0.0710 - val_accuracy: 0.9704 - val_loss: 0.0805 - learning_rate: 5.0000e-05
# Epoch 43/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.9722 - loss: 0.0688 - val_accuracy: 0.9701 - val_loss: 0.0799 - learning_rate: 5.0000e-05
# Epoch 44/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 34s 37ms/step - accuracy: 0.9726 - loss: 0.0684 - val_accuracy: 0.9704 - val_loss: 0.0810 - learning_rate: 5.0000e-05
# Epoch 45/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 32s 35ms/step - accuracy: 0.9738 - loss: 0.0659 - val_accuracy: 0.9701 - val_loss: 0.0805 - learning_rate: 5.0000e-05
# Epoch 46/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 33s 37ms/step - accuracy: 0.9735 - loss: 0.0678 - val_accuracy: 0.9706 - val_loss: 0.0800 - learning_rate: 5.0000e-05
# Epoch 47/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 35s 38ms/step - accuracy: 0.9729 - loss: 0.0662 - val_accuracy: 0.9705 - val_loss: 0.0795 - learning_rate: 5.0000e-05
# Epoch 48/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 31s 34ms/step - accuracy: 0.9739 - loss: 0.0667 - val_accuracy: 0.9712 - val_loss: 0.0806 - learning_rate: 5.0000e-05
# Epoch 49/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 30s 33ms/step - accuracy: 0.9741 - loss: 0.0658 - val_accuracy: 0.9710 - val_loss: 0.0791 - learning_rate: 5.0000e-05
# Epoch 50/50
# 907/907 ━━━━━━━━━━━━━━━━━━━━ 34s 37ms/step - accuracy: 0.9731 - loss: 0.0692 - val_accuracy: 0.9705 - val_loss: 0.0826 - learning_rate: 5.0000e-05
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9730 - loss: 0.0730
# Test Accuracy: 97.26%
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# [[8854  218]
#  [ 278 8783]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      9072
#            1       0.98      0.97      0.97      9061
#
#     accuracy                           0.97     18133
#    macro avg       0.97      0.97      0.97     18133
# weighted avg       0.97      0.97      0.97     18133

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--', label='Chance Line (AUC = 0.5)')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)', fontsize=12)
plt.ylabel('True Positive Rate (TPR)', fontsize=12)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=14)
plt.legend(loc='lower right', fontsize=10)
plt.grid(alpha=0.3)
plt.show()
